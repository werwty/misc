# %%
import argparse
import json
from urllib.parse import urlparse
from tld import get_fld
from adblockparser import AdblockRules

# %%
# Code is from https://gist.github.com/tomatohater/8853161
def parse_har(harfile_path):
    """Reads a har file from the filesystem, converts to CSV, then dumps to
    stdout.
    """
    urls = []
    harfile = open(harfile_path)
    harfile_json = json.loads(harfile.read())
    i = 0

    for entry in harfile_json['log']['entries']:
        i = i + 1
        url = entry['request']['url']
        urlparts = urlparse(entry['request']['url'])
        size_bytes = entry['response']['bodySize']
        size_kilobytes = float(entry['response']['bodySize'])/1024
        mimetype = 'unknown'
        if 'mimeType' in entry['response']['content']:
            mimetype = entry['response']['content']['mimeType']
        urls.append((url, mimetype))
        #print(f"{i}, {url}, {urlparts.hostname}, {size_bytes}, {mimetype}")
    return urls

# %%
easylist = []
with open('./easylist.txt') as f:
    for cnt, line in enumerate(f):
        easylist.append(line.rstrip())
rules = AdblockRules(easylist)

# %%
cnn_urls = parse_har('./www.cnn.com.har')

sites = {}

for url, mimetype in cnn_urls:    
    is_script  = 'script' in mimetype
    is_image = 'image' in mimetype
    domain = 'www.cnn.com'
    try:
        url_domain = get_fld(url)
    except Exception as e:
        print(f"invalid domain in {url}")
        continue
    is_third_party = url_domain != 'cnn.com'
    options = {
        'script': is_script,
        'domain': domain, 
        'image': is_image,
        'third-party': is_third_party
    }
    
    if url_domain not in sites:
        sites[url_domain] = {
            "number_requests": 0,
            "number_requests_blocked":0
        }
        
        
    sites[url_domain]["number_requests"] += 1
    
    
    if rules.should_block(url, options):
        sites[url_domain]["number_requests_blocked"] +=1

        
#print(f"CNN had {number_requests} total requests, and {number_requests_blocked} requests blocked")
# Out:
# invalid domain in https://todo/?google_gid=CAESECD2O5xN3IZm4NHYL1az6ek&google_cver=1&google_push=AeyLB5c6ogjcdHvaAWC4o_iMmkq40-60yoAsz03koX6iroBLlxgzqJZV31BTJ4nlpedPWGjVgN1j-xohR4NRYH1NO00fviA6Deim
# {'cnn.com': {'number_requests': 69, 'number_requests_blocked': 5}, 'googletagservices.com': {'number_requests': 8, 'number_requests_blocked': 2}, 'amazon-adsystem.com': {'number_requests': 10, 'number_requests_blocked': 10}, 'criteo.net': {'number_requests': 3, 'number_requests_blocked': 2}, 'cookielaw.org': {'number_requests': 12, 'number_requests_blocked': 0}, 'outbrain.com': {'number_requests': 16, 'number_requests_blocked': 0}, 'optimizely.com': {'number_requests': 4, 'number_requests_blocked': 0}, 'doubleclick.net': {'number_requests': 44, 'number_requests_blocked': 44}, 'jsdelivr.net': {'number_requests': 1, 'number_requests_blocked': 1}, 'beemray.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'ugdturner.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'adsafeprotected.com': {'number_requests': 31, 'number_requests_blocked': 31}, 'indexww.com': {'number_requests': 1, 'number_requests_blocked': 1}, 'krxd.net': {'number_requests': 9, 'number_requests_blocked': 0}, 'chartbeat.com': {'number_requests': 3, 'number_requests_blocked': 0}, 'bing.com': {'number_requests': 2, 'number_requests_blocked': 0}, 'bounceexchange.com': {'number_requests': 7, 'number_requests_blocked': 0}, 'ads-twitter.com': {'number_requests': 1, 'number_requests_blocked': 1}, 'tru.am': {'number_requests': 2, 'number_requests_blocked': 0}, 'boomtrain.com': {'number_requests': 3, 'number_requests_blocked': 0}, 'segment.com': {'number_requests': 2, 'number_requests_blocked': 0}, 'demdex.net': {'number_requests': 5, 'number_requests_blocked': 0}, 'scorecardresearch.com': {'number_requests': 8, 'number_requests_blocked': 0}, 'tree.com': {'number_requests': 3, 'number_requests_blocked': 0}, 'cloudflare.com': {'number_requests': 2, 'number_requests_blocked': 0}, 'google.com': {'number_requests': 4, 'number_requests_blocked': 4}, 'bleacherreport.net': {'number_requests': 1, 'number_requests_blocked': 0}, 'bootstrapcdn.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'googletagmanager.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'google-analytics.com': {'number_requests': 2, 'number_requests_blocked': 0}, 'lendingtree.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'rlcdn.com': {'number_requests': 3, 'number_requests_blocked': 0}, 'rkdms.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'adsrvr.org': {'number_requests': 6, 'number_requests_blocked': 6}, 'rubiconproject.com': {'number_requests': 18, 'number_requests_blocked': 18}, 'adnxs.com': {'number_requests': 7, 'number_requests_blocked': 7}, 't.co': {'number_requests': 1, 'number_requests_blocked': 0}, 'usabilla.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'everesttech.net': {'number_requests': 3, 'number_requests_blocked': 1}, 'segment.io': {'number_requests': 2, 'number_requests_blocked': 0}, 'yieldmo.com': {'number_requests': 2, 'number_requests_blocked': 2}, 'outbrainimg.com': {'number_requests': 2, 'number_requests_blocked': 0}, '3lift.com': {'number_requests': 3, 'number_requests_blocked': 3}, 'casalemedia.com': {'number_requests': 8, 'number_requests_blocked': 8}, 'facebook.net': {'number_requests': 2, 'number_requests_blocked': 0}, 'googlesyndication.com': {'number_requests': 74, 'number_requests_blocked': 74}, 'imrworldwide.com': {'number_requests': 3, 'number_requests_blocked': 0}, 'turner.com': {'number_requests': 11, 'number_requests_blocked': 8}, 'd9t9vcvz5fqud.cloudfront.net': {'number_requests': 1, 'number_requests_blocked': 0}, 'facebook.com': {'number_requests': 5, 'number_requests_blocked': 2}, 'cnn.io': {'number_requests': 4, 'number_requests_blocked': 0}, 'onetrust.com': {'number_requests': 2, 'number_requests_blocked': 0}, 'bluekai.com': {'number_requests': 2, 'number_requests_blocked': 0}, 'zemanta.com': {'number_requests': 2, 'number_requests_blocked': 2}, 'im-apps.net': {'number_requests': 1, 'number_requests_blocked': 0}, 'agkn.com': {'number_requests': 1, 'number_requests_blocked': 0}, 'mfadsrvr.co ...

# %%
macys_urls = parse_har('./www.macys.com.har')

for url, mimetype in macys_urls:    
    is_script  = 'script' in mimetype
    is_image = 'image' in mimetype
    domain = 'www.macys.com'
    try:
        url_domain = get_fld(url)
    except Exception as e:
        print(f"invalid domain in {url}")
        continue
    is_third_party = url_domain != 'macys.com'
    options = {
        'script': is_script,
        'domain': domain, 
        'image': is_image,
        'third-party': is_third_party
    }
    
    if url_domain not in sites:
        sites[url_domain] = {
            "number_requests": 0,
            "number_requests_blocked":0
        }
        
        
    sites[url_domain]["number_requests"] += 1
    
    
    if rules.should_block(url, options):
        sites[url_domain]["number_requests_blocked"] +=1

# %%
print("Site, # HTTP requests, # HTTP requests blocked")
for site, requests in sites.items():
    print(f"{site}, {requests['number_requests']}, {requests['number_requests_blocked']}")
# Out:
# Site, # HTTP requests, # HTTP requests blocked
# cnn.com, 69, 5
# googletagservices.com, 8, 2
# amazon-adsystem.com, 10, 10
# criteo.net, 6, 4
# cookielaw.org, 12, 0
# outbrain.com, 19, 0
# optimizely.com, 4, 0
# doubleclick.net, 48, 46
# jsdelivr.net, 1, 1
# beemray.com, 1, 0
# ugdturner.com, 1, 0
# adsafeprotected.com, 31, 31
# indexww.com, 1, 1
# krxd.net, 10, 0
# chartbeat.com, 3, 0
# bing.com, 5, 0
# bounceexchange.com, 7, 0
# ads-twitter.com, 2, 2
# tru.am, 2, 0
# boomtrain.com, 3, 0
# segment.com, 2, 0
# demdex.net, 9, 0
# scorecardresearch.com, 8, 0
# tree.com, 3, 0
# cloudflare.com, 2, 0
# google.com, 5, 4
# bleacherreport.net, 1, 0
# bootstrapcdn.com, 1, 0
# googletagmanager.com, 2, 0
# google-analytics.com, 4, 0
# lendingtree.com, 1, 0
# rlcdn.com, 6, 0
# rkdms.com, 1, 0
# adsrvr.org, 6, 6
# rubiconproject.com, 19, 19
# adnxs.com, 10, 10
# t.co, 2, 0
# usabilla.com, 1, 0
# everesttech.net, 4, 1
# segment.io, 2, 0
# yieldmo.com, 2, 2
# outbrainimg.com, 2, 0
# 3lift.com, 3, 3
# casalemedia.com, 10, 10
# facebook.net, 4, 0
# googlesyndication.com, 74, 74
# imrworldwide.com, 3, 0
# turner.com, 11, 8
# d9t9vcvz5fqud.cloudfront.net, 1, 0
# facebook.com, 7, 2
# cnn.io, 4, 0
# onetrust.com, 2, 0
# bluekai.com, 3, 0
# zemanta.com, 2, 2
# im-apps.net, 1, 0
# agkn.com, 4, 0
# mfadsrvr.com, 2, 0
# bidswitch.net, 7, 0
# criteo.com, 6, 3
# navdmp.com, 1, 0
# adition.com, 1, 1
# powerlinks.com, 1, 1
# eyeota.net, 2, 0
# exelator.com, 4, 0
# geistm.com, 1, 0
# bttrack.com, 1, 1
# crwdcntrl.net, 1, 0
# creativecdn.com, 2, 2
# quantserve.com, 2, 0
# trustx.org, 1, 1
# moatads.com, 7, 7
# turn.com, 8, 8
# 2mdn.net, 3, 3
# mathtag.com, 16, 0
# sharedid.org, 1, 0
# atdmt.com, 1, 0
# yahoo.com, 7, 2
# dyntrk.com, 2, 2
# 1rx.io, 4, 4
# media.net, 2, 2
# smartadserver.com, 1, 1
# fonts.googleapis.com, 2, 0
# sitescout.com, 3, 3
# impdesk.com, 1, 0
# socdm.com, 1, 0
# gstatic.com, 22, 0
# flashtalking.com, 25, 8
# truste.com, 1, 1
# bouncex.net, 18, 0
# tidaltv.com, 7, 7
# tapad.com, 5, 5
# emxdgt.com, 1, 0
# adswizz.com, 1, 0
# advertising.com, 2, 0
# addthis.com, 1, 0
# spotxchange.com, 1, 1
# fwmrm.net, 1, 0
# videohub.tv, 1, 0
# pubmatic.com, 62, 62
# truoptik.com, 2, 0
# yieldoptimizer.com, 2, 2
# iasds01.com, 2, 0
# twitter.com, 2, 0
# chartbeat.net, 33, 0
# summerhamster.com, 1, 0
# trustarc.com, 6, 0
# behave.com, 6, 0
# adsymptotic.com, 7, 4
# netmng.com, 1, 0
# simpli.fi, 2, 2
# bidr.io, 4, 0
# adentifi.com, 1, 1
# tribalfusion.com, 2, 2
# w55c.net, 1, 1
# owneriq.net, 9, 1
# resetdigital.co, 1, 0
# taboola.com, 3, 1
# serverbid.com, 1, 1
# adgrx.com, 1, 1
# mxptint.net, 2, 0
# dotomi.com, 2, 2
# ipredictive.com, 1, 1
# gumgum.com, 1, 1
# adform.net, 4, 2
# rundsp.com, 1, 0
# acuityplatform.com, 1, 1
# zorosrv.com, 1, 0
# technoratimedia.com, 1, 1
# eyereturn.com, 1, 1
# appier.net, 1, 0
# brealtime.com, 1, 1
# adhigh.net, 2, 2
# contextweb.com, 2, 2
# gwallet.com, 3, 3
# bidtheatre.com, 1, 1
# macys.com, 13, 0
# macysassets.com, 51, 0
# tiqcdn.com, 24, 0
# go-mpulse.net, 2, 0
# omtrdc.net, 4, 0
# narrativ.com, 2, 0
# yimg.com, 1, 0
# hlserve.com, 1, 1
# d1n00d49gkbray.cloudfront.net, 1, 0
# pinimg.com, 2, 0
# rmtag.com, 2, 0
# medallia.com, 2, 0
# akamaihd.net, 4, 0
# bam-x.com, 3, 0
# storetail.net, 1, 0
# ibmcloud.com, 5, 0
# openx.net, 3, 3
# linksynergy.com, 1, 0
# pinterest.com, 3, 0
# kampyle.com, 3, 0
# akstat.io, 1, 0
# reson8.com, 1, 0
# digitru.st, 1, 0
# smarterhq.io, 1, 0
